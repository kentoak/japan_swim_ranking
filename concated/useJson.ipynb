# %%
import json
from pprint import pprint 
from dictknife import deepmerge 
from collections import defaultdict
import csv
#sample
waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}
swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}

i=2021
gender_code=1
waterway_code=1
swimming_style_code=1
distance_code=5
nameDict=defaultdict(list)#{}
topTen=[[] for i in range(15)]
#print(topTen)
for i in range(2008,2023):
    jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
    path='/'+str(i)+'_rank200/'+jname+".json"
    print(path)
    year=i
    with open(path) as f:
        s = f.read()
        dat = dict(json.loads(s))['data']
        for k,i in enumerate(dat):
            #print(i["swimmers"]["swimmer_name"])
            name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
            if k<10:
                topTen[year-2008].append(name)
            #print(type(name))
            #print(name)
            info=i["record"]
            info["year"]=year
            #print(i["record"]["achieve_date"])
            info['entry_group']=i["swimmers"]['entry_group']
            if name=="瀬戸大也":
                print(name)
                print(info)
            nameDict[name].append(info)
#pprint(topTen)
isTopTen=list(set(sum(topTen, [])))
print(isTopTen)
with open('../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'.csv', 'w') as f:
    writer = csv.writer(f)
    for i in range(len(topTen)):
        for j in topTen[-i-1]:
            #print(nameDict[j])
            da=nameDict[j]
            if j in isTopTen:
                print(isTopTen[isTopTen.index(j)])
                isTopTen.pop(isTopTen.index(j))
                for k in da:
                    writer.writerow([k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"]])
                    #print(k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"])
# Out:
# 2008_Men_LCM_400M_Fr_200all.json
# 2009_Men_LCM_400M_Fr_200all.json
# 2010_Men_LCM_400M_Fr_200all.json
# 2011_Men_LCM_400M_Fr_200all.json
# 瀬戸大也
# {'id': 18202074, 'is_relay_first': False, 'record': '3:50.93', 'achieve_date': '2011年09月11日(日)', 'is_new': False, 'year': 2011, 'entry_group': {'code': '11Z01', 'name': '埼  玉', 'short_name': '埼  玉', 'member_group': {'code': 11, 'name': '埼玉'}}}
# 2012_Men_LCM_400M_Fr_200all.json
# 瀬戸大也
# {'id': 13786580, 'is_relay_first': False, 'record': '3:48.78', 'achieve_date': '2012年09月17日(月)', 'is_new': False, 'year': 2012, 'entry_group': {'code': '11Z01', 'name': '埼  玉', 'short_name': '埼  玉', 'member_group': {'code': 11, 'name': '埼玉'}}}
# 2013_Men_LCM_400M_Fr_200all.json
# 瀬戸大也
# {'id': 15200560, 'is_relay_first': False, 'record': '3:51.24', 'achieve_date': '2013年09月13日(金)', 'is_new': False, 'year': 2013, 'entry_group': {'code': '11Z01', 'name': '埼  玉', 'short_name': '埼  玉', 'member_group': {'code': 11, 'name': '埼玉'}}}
# ...

# %%
import json
from pprint import pprint 
from dictknife import deepmerge 
from collections import defaultdict
import csv

waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}
swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}

i=2021
gender_code=1
waterway_code=1
swimming_style_code=1
distance_code=5

for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:#もしIMなら,,,
                print(swimming_style_code_dict[swimming_style_code])
                for distance_code in range(5,3,-1):
                    nameDict=defaultdict(list)#{}
                    topTen=[[] for i in range(15)]
                    for i in range(2008,2023):
                        jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
                        path='/'+str(i)+'_rank200/'+jname+".json"
                        year=i
                        with open(path) as f:
                            s = f.read()
                            dat = dict(json.loads(s))['data']
                            for k,i in enumerate(dat):
                                #print(i["swimmers"]["swimmer_name"])
                                name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
                                if k<10:
                                    topTen[year-2008].append(name)
                                #print(type(name))
                                #print(name)
                                info=i["record"]
                                info["year"]=year
                                #print(i["record"]["achieve_date"])
                                info['entry_group']=i["swimmers"]['entry_group']
                                nameDict[name].append(info)
                    #pprint(topTen)
                    isTopTen=list(set(sum(topTen, [])))
                    with open('../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'.csv', 'w') as f:
                        writer = csv.writer(f)
                        for i in range(len(topTen)):
                            for j in topTen[-i-1]:
                                #print(nameDict[j])
                                da=nameDict[j]
                                if j in isTopTen:
                                    #print(isTopTen[isTopTen.index(j)])
                                    isTopTen.pop(isTopTen.index(j))
                                    for k in da:
                                        writer.writerow([k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"]])
                                        #print(k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"])
            elif swimming_style_code==1:#もしFrなら,,,
                print(swimming_style_code_dict[swimming_style_code])
                for distance_code in range(7,1,-1):
                    nameDict=defaultdict(list)#{}
                    topTen=[[] for i in range(15)]
                    for i in range(2008,2023):
                        jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
                        path=jname+".json"
                        year=i
                        with open(path) as f:
                            s = f.read()
                            dat = dict(json.loads(s))['data']
                            for k,i in enumerate(dat):
                                #print(i["swimmers"]["swimmer_name"])
                                name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
                                if k<10:
                                    topTen[year-2008].append(name)
                                #print(type(name))
                                #print(name)
                                info=i["record"]
                                info["year"]=year
                                #print(i["record"]["achieve_date"])
                                info['entry_group']=i["swimmers"]['entry_group']
                                nameDict[name].append(info)
                    #pprint(topTen)
                    isTopTen=list(set(sum(topTen, [])))
                    with open('../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'.csv', 'w') as f:
                        writer = csv.writer(f)
                        for i in range(len(topTen)):
                            for j in topTen[-i-1]:
                                #print(nameDict[j])
                                da=nameDict[j]
                                if j in isTopTen:
                                    isTopTen.pop(isTopTen.index(j))
                                    for k in da:
                                        writer.writerow([k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"]])
                                        #print(k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"])
            else:#もしIM,Fr以外なら,,,
                print(swimming_style_code_dict[swimming_style_code])
                for distance_code in range(4,1,-1):
                    nameDict=defaultdict(list)#{}
                    topTen=[[] for i in range(15)]
                    for i in range(2008,2023):
                        jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
                        path=jname+".json"
                        #print(path)
                        year=i
                        with open(path) as f:
                            s = f.read()
                            dat = dict(json.loads(s))['data']
                            for k,i in enumerate(dat):
                                #print(i["swimmers"]["swimmer_name"])
                                name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
                                if k<10:
                                    topTen[year-2008].append(name)
                                #print(type(name))
                                #print(name)
                                info=i["record"]
                                info["year"]=year
                                #print(i["record"]["achieve_date"])
                                info['entry_group']=i["swimmers"]['entry_group']
                                nameDict[name].append(info)
                    #pprint(topTen)
                    isTopTen=list(set(sum(topTen, [])))
                    with open('../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'.csv', 'w') as f:
                        writer = csv.writer(f)
                        for i in range(len(topTen)):
                            for j in topTen[-i-1]:
                                #print(nameDict[j])
                                da=nameDict[j]
                                if j in isTopTen:
                                    #print(isTopTen[isTopTen.index(j)])
                                    isTopTen.pop(isTopTen.index(j))
                                    for k in da:
                                        writer.writerow([k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"]])
                                        #print(k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"])
# Out:
# IM
# Fly
# Br
# Ba
# Fr
# IM
# Fly
# Br
# Ba
# Fr

# %%
import json
from pprint import pprint 
from dictknife import deepmerge 
from collections import defaultdict
import csv
import json
import pandas as pd
import numpy as np
import datetime as dt

#sample
waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}
swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}

i=2021
gender_code=1
waterway_code=1
swimming_style_code=1
distance_code=5
nameDict=defaultdict(list)#{}
topTen=[[] for i in range(15)]
#print(topTen)
for i in range(2008,2023):
    jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
    path='/'+str(i)+'_rank200/'+jname+".json"
    year=i
    with open(path) as f:
        s = f.read()
        dat = dict(json.loads(s))['data']
        for k,i in enumerate(dat):
            #print(i["swimmers"]["swimmer_name"])
            name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
            if k<10:
                topTen[year-2008].append(name)
            #print(type(name))
            #print(name)
            info=i["record"]
            info["year"]=year
            #print(i["record"]["achieve_date"])
            info['entry_group']=i["swimmers"]['entry_group']
            nameDict[name].append(info)
#pprint(topTen)
isTopTen=list(set(sum(topTen, [])))
#with open('../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'_pandas.csv', 'w') as f:
    #writer = csv.writer(f)
df = pd.DataFrame(
    data={'col1': [i for i in range(2008,2023)]},
    index=[i for i in range(2008,2023)]
)
datname='../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'_pandas.csv'
base_time = dt.datetime.strptime('00:00.0', '%M:%S.%f')
#print(base_time)
for i in range(len(topTen)):
    for j in topTen[-i-1]:
        #print(nameDict[j])
        da=nameDict[j]
        if j in isTopTen:
            isTopTen.pop(isTopTen.index(j))
            df[j]=np.nan
            for k in da:
                #print(type(dt.datetime.strptime(k['record'],"%M:%S.%f")))
                #print((dt.datetime.strptime(k['record'],"%M:%S.%f")-base_time).total_seconds())
                #print(type((dt.datetime.strptime(k['record'],"%M:%S.%f")-base_time).total_seconds()))
                if ":" in k['record']:
                    df[j].loc[k["year"]] = (dt.datetime.strptime(k['record'],"%M:%S.%f")-base_time).total_seconds()
                else:
                    df[j].loc[k["year"]] = float(k["record"])
                #writer.writerow([k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"]])
                #print(k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"])

df=df.drop(columns='col1')
print(df)
#df.to_csv(datname)
# Out:
#         井本一輝    田渕海斗    尾﨑健太    江原騎士    黒川紫唯    吉田啓祐    渡邊天馬    桐山真葵    宮木宏悦  \
# 2008     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2009     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2010     NaN     NaN     NaN  244.01     NaN     NaN     NaN     NaN     NaN
# 2011     NaN     NaN     NaN  240.50     NaN     NaN     NaN     NaN     NaN
# 2012     NaN     NaN     NaN  231.82     NaN     NaN     NaN     NaN     NaN
# 2013     NaN     NaN     NaN  229.83     NaN     NaN     NaN     NaN     NaN
# 2014     NaN     NaN  242.40  229.86     NaN     NaN     NaN     NaN     NaN
# 2015     NaN     NaN  242.15  228.47     NaN  240.05     NaN     NaN     NaN
# 2016     NaN     NaN  236.27  227.43     NaN  235.08     NaN     NaN     NaN
# 2017  237.46     NaN  234.88  227.18  238.52  231.64  243.78     NaN     NaN
# 2018  235.78  243.48  237.07  226.64  234.34  228.51     NaN     NaN     NaN
# ...

# %%
import json
from pprint import pprint 
from dictknife import deepmerge 
from collections import defaultdict
import csv

waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}
swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}

i=2021
gender_code=1
waterway_code=1
swimming_style_code=1
distance_code=5
base_time = dt.datetime.strptime('00:00.0', '%M:%S.%f')
for gender_code in range(2,0,-1):
    for waterway_code in range(1,2):
        for swimming_style_code in range(5,0,-1):
            if swimming_style_code==5:#もしIMなら,,,
                print(swimming_style_code_dict[swimming_style_code])
                for distance_code in range(5,3,-1):
                    nameDict=defaultdict(list)#{}
                    topTen=[[] for i in range(15)]
                    for i in range(2008,2023):
                        jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
                        path='/'+str(i)+'_rank200/'+jname+".json"
                        year=i
                        with open(path) as f:
                            s = f.read()
                            dat = dict(json.loads(s))['data']
                            for k,i in enumerate(dat):
                                #print(i["swimmers"]["swimmer_name"])
                                name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
                                if k<10:
                                    topTen[year-2008].append(name)
                                #print(type(name))
                                #print(name)
                                info=i["record"]
                                info["year"]=year
                                #print(i["record"]["achieve_date"])
                                info['entry_group']=i["swimmers"]['entry_group']
                                nameDict[name].append(info)
                    #pprint(topTen)
                    isTopTen=list(set(sum(topTen, [])))
                    df = pd.DataFrame(
                        data={'col1': [i for i in range(2008,2023)]},
                        index=[i for i in range(2008,2023)]
                    )
                    datname='../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'_pandas.csv'
                    for i in range(len(topTen)):
                        for j in topTen[-i-1]:
                            #print(nameDict[j])
                            da=nameDict[j]
                            if j in isTopTen:
                                #print(isTopTen[isTopTen.index(j)])
                                isTopTen.pop(isTopTen.index(j))
                                df[j]=np.nan
                                for k in da:
                                    #df[j].loc[k["year"]] = k['record']
                                    if ":" in k['record']:
                                        df[j].loc[k["year"]] = (dt.datetime.strptime(k['record'],"%M:%S.%f")-base_time).total_seconds()
                                    else:
                                        df[j].loc[k["year"]] = float(k["record"])
                                    #print(k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"])
                    
                    df.to_csv(datname)
            elif swimming_style_code==1:#もしFrなら,,,
                print(swimming_style_code_dict[swimming_style_code])
                for distance_code in range(7,1,-1):
                    nameDict=defaultdict(list)#{}
                    topTen=[[] for i in range(15)]
                    for i in range(2008,2023):
                        jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
                        path=jname+".json"
                        year=i
                        with open(path) as f:
                            s = f.read()
                            dat = dict(json.loads(s))['data']
                            for k,i in enumerate(dat):
                                #print(i["swimmers"]["swimmer_name"])
                                name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
                                if k<10:
                                    topTen[year-2008].append(name)
                                #print(type(name))
                                #print(name)
                                info=i["record"]
                                info["year"]=year
                                #print(i["record"]["achieve_date"])
                                info['entry_group']=i["swimmers"]['entry_group']
                                nameDict[name].append(info)
                    #pprint(topTen)
                    isTopTen=list(set(sum(topTen, [])))
                    df = pd.DataFrame(
                        data={'col1': [i for i in range(2008,2023)]},
                        index=[i for i in range(2008,2023)]
                    )
                    datname='../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'_pandas.csv'
                    for i in range(len(topTen)):
                        for j in topTen[-i-1]:
                            #print(nameDict[j])
                            da=nameDict[j]
                            if j in isTopTen:
                                #print(isTopTen[isTopTen.index(j)])
                                isTopTen.pop(isTopTen.index(j))
                                df[j]=np.nan
                                for k in da:
                                    #df[j].loc[k["year"]] = k['record']
                                    if ":" in k['record']:
                                        df[j].loc[k["year"]] = (dt.datetime.strptime(k['record'],"%M:%S.%f")-base_time).total_seconds()
                                    else:
                                        df[j].loc[k["year"]] = float(k["record"])
                                    #print(k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"])
                    df=df.drop(columns='col1')
                    df.to_csv(datname)
            else:#もしIM,Fr以外なら,,,
                print(swimming_style_code_dict[swimming_style_code])
                for distance_code in range(4,1,-1):
                    nameDict=defaultdict(list)#{}
                    topTen=[[] for i in range(15)]
                    for i in range(2008,2023):
                        jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
                        path=jname+".json"
                        #print(path)
                        year=i
                        with open(path) as f:
                            s = f.read()
                            dat = dict(json.loads(s))['data']
                            for k,i in enumerate(dat):
                                #print(i["swimmers"]["swimmer_name"])
                                name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
                                if k<10:
                                    topTen[year-2008].append(name)
                                #print(type(name))
                                #print(name)
                                info=i["record"]
                                info["year"]=year
                                #print(i["record"]["achieve_date"])
                                info['entry_group']=i["swimmers"]['entry_group']
                                nameDict[name].append(info)
                    #pprint(topTen)
                    isTopTen=list(set(sum(topTen, [])))
                    df = pd.DataFrame(
                        data={'col1': [i for i in range(2008,2023)]},
                        index=[i for i in range(2008,2023)]
                    )
                    datname='../topTens/'+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+'_pandas.csv'
                    for i in range(len(topTen)):
                        for j in topTen[-i-1]:
                            #print(nameDict[j])
                            da=nameDict[j]
                            if j in isTopTen:
                                #print(isTopTen[isTopTen.index(j)])
                                isTopTen.pop(isTopTen.index(j))
                                df[j]=np.nan
                                for k in da:
                                    #df[j].loc[k["year"]] = k['record']
                                    if ":" in k['record']:
                                        df[j].loc[k["year"]] = (dt.datetime.strptime(k['record'],"%M:%S.%f")-base_time).total_seconds()
                                    else:
                                        df[j].loc[k["year"]] = float(k["record"])
                                    #print(k["year"],j,k["entry_group"]["name"],k['record'],k["achieve_date"])
                    df=df.drop(columns='col1')
                    df.to_csv(datname)
# Out:
# IM
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# Fly
# Br
# Ba
# Fr
# IM
# Fly
# Br
# Ba
# Fr
