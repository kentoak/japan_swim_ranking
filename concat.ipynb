# %%
# !pip install dictknife
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 403.9 kB/s eta 0:00:00a 0:00:01
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from dictknife import deepmerge 
waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}
swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
allpage=4

#sample
#これはサンプルです

j=[]
i=2021
gender_code=1
waterway_code=1
swimming_style_code=1
distance_code=5
for p in range(1,allpage+1):
    jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
    path=jname+".json"
    #print(path)
    with open(path) as f:
        s = f.read()
        #print(type(dict(json.loads(s))))
        s = dict(json.loads(s))['data']
        j.append(s)
tmp=j[0]
for k in range(1,allpage):
    tmp=deepmerge(tmp, j[k])
#print(tmp)
#print(type(tmp))
#print(type(json.loads(tmp)))
newPath = "./concated/"+str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"200all"+".json"
#print(newPath)
with open(newPath,mode='w') as fw:
    dat = {}
    dat["data"]=tmp#json.loads(tmp)
    fw.write(json.dumps(dat))
# Out:
# <class 'list'>

# %%
#ここから

# %%
import json
from dictknife import deepmerge

waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}
swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
allpage=4
for i in range(2008,2023):
    for gender_code in range(2,0,-1):
        for waterway_code in range(1,3):
            for swimming_style_code in range(5,0,-1):
                if swimming_style_code==5:#もしIMなら,,,
                    #print(swimming_style_code_dict[swimming_style_code])
                    for distance_code in range(5,3,-1):
                        j=[]
                        for p in range(1,allpage+1):
                            jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                            path='./'+str(i)+'_rank/'+jname+".json"
                            #print(path)
                            with open(path) as f:
                                s = f.read()
                                #print(type(dict(json.loads(s))))
                                s = dict(json.loads(s))['data']
                                j.append(s)
                        tmp=j[0]
                        for k in range(1,allpage):
                            tmp=deepmerge(tmp, j[k])
                        #print(tmp[0])
                        newPath = "./concated/"+str(i)+"_rank200/"+str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"200all"+".json"
                        #print(newPath)
                        with open(newPath,mode='w') as fw:
                            dat = {}
                            dat["data"]=tmp
                            fw.write(json.dumps(dat))
                elif swimming_style_code==1:#もしFrなら,,,
                    print(swimming_style_code_dict[swimming_style_code])
                    for distance_code in range(7,1,-1):
                        j=[]
                        for p in range(1,allpage+1):
                            jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                            path='./'+str(i)+'_rank/'+jname+".json"
                            print(path)
                            with open(path) as f:
                                s = f.read()
                                #print(type(dict(json.loads(s))))
                                #s = dict(json.loads(s))['data']
                                s = dict(json.loads(s))['data']
                                j.append(s)
                        tmp=j[0]   
                        for k in range(1,allpage):
                            tmp=deepmerge(tmp, j[k])
                        #print(tmp[0])
                        newPath = "./concated/"+str(i)+"_rank200/"+str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"200all"+".json"
                        #print(newPath)
                        with open(newPath,mode='w') as fw:
                            dat = {}
                            dat["data"]=tmp
                            fw.write(json.dumps(dat))
                else:#もしIM,Fr以外なら,,,
                    print(swimming_style_code_dict[swimming_style_code])
                    for distance_code in range(4,1,-1):
                        j=[]
                        for p in range(1,allpage+1):
                            jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"rank"+str(1+50*(p-1))+"-"+str(50*(p))
                            path='./'+str(i)+'_rank/'+jname+".json"
                            #print(path)
                            with open(path) as f:
                                s = f.read()
                                #print(type(dict(json.loads(s))))
                                #s = dict(json.loads(s))['data']
                                s = dict(json.loads(s))['data']
                                j.append(s)
                        tmp=j[0] 
                        #print(tmp[0])
                        for k in range(1,allpage):
                            tmp=deepmerge(tmp, j[k])
                        newPath = "./concated/"+str(i)+"_rank200/"+str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_"+"200all"+".json"
                        #print(newPath)
                        with open(newPath,mode='w') as fw:
                            dat = {}
                            dat["data"]=tmp
                            fw.write(json.dumps(dat))
# Out:
# Fly
# Br
# Ba
# Fr
# ./2008_rank/2008_Women_LCM_1500M_Fr_rank1-50.json
# ./2008_rank/2008_Women_LCM_1500M_Fr_rank51-100.json
# ./2008_rank/2008_Women_LCM_1500M_Fr_rank101-150.json
# ./2008_rank/2008_Women_LCM_1500M_Fr_rank151-200.json
# ./2008_rank/2008_Women_LCM_800M_Fr_rank1-50.json
# ./2008_rank/2008_Women_LCM_800M_Fr_rank51-100.json
# ./2008_rank/2008_Women_LCM_800M_Fr_rank101-150.json
# ./2008_rank/2008_Women_LCM_800M_Fr_rank151-200.json
# ./2008_rank/2008_Women_LCM_400M_Fr_rank1-50.json
# ./2008_rank/2008_Women_LCM_400M_Fr_rank51-100.json
# ./2008_rank/2008_Women_LCM_400M_Fr_rank101-150.json
# ./2008_rank/2008_Women_LCM_400M_Fr_rank151-200.json
# ./2008_rank/2008_Women_LCM_200M_Fr_rank1-50.json
# ./2008_rank/2008_Women_LCM_200M_Fr_rank51-100.json
# ./2008_rank/2008_Women_LCM_200M_Fr_rank101-150.json
# ./2008_rank/2008_Women_LCM_200M_Fr_rank151-200.json
# ./2008_rank/2008_Women_LCM_100M_Fr_rank1-50.json
# ./2008_rank/2008_Women_LCM_100M_Fr_rank51-100.json
# ...
