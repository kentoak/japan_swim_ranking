# %%
import json
from pprint import pprint 
from dictknife import deepmerge 
from collections import defaultdict
import csv

waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}
swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
def get_keys_from_value(d, val):
    keys=[k for k, v in d.items() if v == val]
    if keys:
        return keys[0]
    return None

names=["宮下純一","森田智己","入江陵介","中野高"]
discribe=["Men","LCM","100M","Ba"]

gender_code=get_keys_from_value(gender_code_dict,discribe[0])
waterway_code=get_keys_from_value(waterway_code_dict,discribe[1])
distance_code=get_keys_from_value(distance_code_dict,discribe[2])
swimming_style_code=get_keys_from_value(swimming_style_code_dict,discribe[3])


nameDict={}
#print('_'.join(names))
for n in names:
    swimmerName=n
    nameList=[]
    for i in range(2008,2023):
        jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
        path='./concated/'+str(i)+'_rank200/'+jname+".json"
        year=i
        with open(path) as f:
            s = f.read()
            dat = dict(json.loads(s))['data']
            for k,i in enumerate(dat):
                #print(i["swimmers"]["swimmer_name"])
                name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
                info=i["record"]
                info["year"]=year
                #print(i["record"]["achieve_date"])
                info['entry_group']=i["swimmers"]['entry_group']
                if name==swimmerName:
                    #print(info)
                    nameList.append(info)
    nameDict[swimmerName]=nameList
#pprint(nameDict)
filename=str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])
with open('./namesbox/'+'_'.join(names)+"_"+filename+'.csv', 'w') as f:
    writer = csv.writer(f)
    for swimmerName in names:
        print(swimmerName)
        for k in nameDict[swimmerName]:
            print(k)
            writer.writerow([swimmerName,k["year"],k["entry_group"]["name"],k['record'],k["achieve_date"]])
# Out:
# 宮下純一
# {'id': 2819464, 'is_relay_first': False, 'record': '54.01', 'achieve_date': '2008年06月06日(金)', 'is_new': False, 'year': 2008, 'entry_group': {'code': '13772', 'name': 'ﾎﾘﾌﾟﾛ', 'short_name': 'TACMS', 'member_group': {'code': 13, 'name': '東京'}}}
# 森田智己
# {'id': 2818126, 'is_relay_first': False, 'record': '54.03', 'achieve_date': '2008年04月16日(水)', 'is_new': False, 'year': 2008, 'entry_group': {'code': '12551', 'name': 'ｾﾝﾄﾗﾙｽﾎﾟｰﾂ', 'short_name': 'ｾﾝﾄﾗﾙｽﾎﾟｰﾂ', 'member_group': {'code': 12, 'name': '千葉'}}}
# 入江陵介
# {'id': 2860387, 'is_relay_first': False, 'record': '53.93', 'achieve_date': '2008年09月07日(日)', 'is_new': False, 'year': 2008, 'entry_group': {'code': '50010', 'name': '近畿大', 'short_name': '近畿大学', 'member_group': {'code': 50, 'name': '関西支部'}}}
# {'id': 4346638, 'is_relay_first': False, 'record': '52.37', 'achieve_date': '2009年09月12日(土)', 'is_new': False, 'year': 2009, 'entry_group': {'code': '2799Z', 'name': '大    阪', 'short_name': '大\u3000阪', 'member_group': {'code': 27, 'name': '大阪'}}}
# {'id': 520583, 'is_relay_first': True, 'record': '53.09', 'achieve_date': '2010年09月12日(日)', 'is_new': False, 'year': 2010, 'entry_group': {'code': '2799Z', 'name': '大\u3000阪', 'short_name': '大\u3000阪', 'member_group': {'code': 27, 'name': '大阪'}}}
# {'id': 901363, 'is_relay_first': True, 'record': '52.83', 'achieve_date': '2011年09月03日(土)', 'is_new': False, 'year': 2011, 'entry_group': {'code': '50010', 'name': '近畿大学', 'short_name': '近畿大学', 'member_group': {'code': 50, 'name': '関西支部'}}}
# {'id': 13796808, 'is_relay_first': False, 'record': '52.91', 'achieve_date': '2012年04月04日(水)', 'is_new': False, 'year': 2012, 'entry_group': {'code': '27218', 'name': 'ＪＡＰＡＮ', 'short_name': 'MGST', 'member_group': {'code': 27, 'name': '大阪'}}}
# {'id': 15472114, 'is_relay_first': False, 'record': '50.71', 'achieve_date': '2013年08月10日(土)', 'is_new': False, 'year': 2013, 'entry_group': {'code': '27218', 'name': 'ＪＡＰＡＮ', 'short_name': 'MGST', 'member_group': {'code': 27, 'name': '大阪'}}}
# {'id': 5937839, 'is_relay_first': False, 'record': '52.34', 'achieve_date': '2014年09月21日(日)', 'is_new': False, 'year': 2014, 'entry_group': {'code': '27218', 'name': 'ＪＡＰＡＮ', 'short_name': 'MGST', 'member_group': {'code': 27, 'name': '大阪'}}}
# {'id': 8753238, 'is_relay_first': False, 'record': '52.99', 'achieve_date': '2015年04月08日(水)', 'is_new': False, 'year': 2015, 'entry_group': {'code': '27218', 'name': 'ＪＡＰＡＮ', 'short_name': 'MGST', 'member_group': {'code': 27, 'name': '大阪'}}}
# {'id': 16972305, 'is_relay_first': False, 'record': '53.21', 'achieve_date': '2016年08月07日(日)', 'is_new': False, 'year': 2016, 'entry_group': {'code': '27218', 'name': 'ＪＡＰＡＮ', 'short_name': 'MGST', 'member_group': {'code': 27, 'name': '大阪'}}}
# {'id': 19962413, 'is_relay_first': False, 'record': '53.02', 'achieve_date': '2017年07月24日(月)', 'is_new': False, 'year': 2017, 'entry_group': {'code': '13597', 'name': 'ｲﾄﾏﾝﾄｳｼﾝ', 'short_name': 'イトマン東進', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 11880607, 'is_relay_first': False, 'record': '52.53', 'achieve_date': '2018年08月19日(日)', 'is_new': False, 'year': 2018, 'entry_group': {'code': '13597', 'name': 'ｲﾄﾏﾝﾄｳｼﾝ', 'short_name': 'イトマン東進', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 7360471, 'is_relay_first': False, 'record': '52.59', 'achieve_date': '2020年01月24日(金)', 'is_new': False, 'year': 2019, 'entry_group': {'code': '13597', 'name': 'ｲﾄﾏﾝﾄｳｼﾝ', 'short_name': 'イトマン東進', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 12926510, 'is_relay_first': False, 'record': '53.04', 'achieve_date': '2020年12月04日(金)', 'is_new': False, 'year': 2020, 'entry_group': {'code': '13597', 'name': 'ｲﾄﾏﾝﾄｳｼﾝ', 'short_name': 'イトマン東進', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 23631564, 'is_relay_first': False, 'record': '52.94', 'achieve_date': '2022年03月03日(木)', 'is_new': False, 'year': 2021, 'entry_group': {'code': '13597', 'name': 'イトマン東進', 'short_name': 'イトマン東進', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 24561329, 'is_relay_first': False, 'record': '52.83', 'achieve_date': '2022年06月21日(火)', 'is_new': False, 'year': 2022, 'entry_group': {'code': '13597', 'name': 'JPN', 'short_name': 'イトマン東進', 'member_group': {'code': 13, 'name': '東京'}}}
# 中野高
# {'id': 3351882, 'is_relay_first': False, 'record': '54.67', 'achieve_date': '2009年02月01日(日)', 'is_new': False, 'year': 2008, 'entry_group': {'code': '13771', 'name': 'ﾐｽﾞﾉ', 'short_name': 'ミズノ', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 3760969, 'is_relay_first': False, 'record': '54.11', 'achieve_date': '2009年04月17日(金)', 'is_new': False, 'year': 2009, 'entry_group': {'code': '13771', 'name': 'ﾐｽﾞﾉ', 'short_name': 'ミズノ', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 10185992, 'is_relay_first': False, 'record': '54.90', 'achieve_date': '2010年04月14日(水)', 'is_new': False, 'year': 2010, 'entry_group': {'code': '13780', 'name': 'TBSﾃﾚﾋﾞ', 'short_name': 'TBSﾃﾚﾋﾞ', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 18226043, 'is_relay_first': False, 'record': '55.95', 'achieve_date': '2011年04月09日(土)', 'is_new': False, 'year': 2011, 'entry_group': {'code': '13780', 'name': 'TBSﾃﾚﾋﾞ', 'short_name': 'TBSﾃﾚﾋﾞ', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 13796541, 'is_relay_first': False, 'record': '55.81', 'achieve_date': '2012年04月03日(火)', 'is_new': False, 'year': 2012, 'entry_group': {'code': '14507', 'name': '林水泳教室', 'short_name': '林水泳教室', 'member_group': {'code': 14, 'name': '神奈川'}}}
