# %%
import json
from pprint import pprint 
from dictknife import deepmerge 
from collections import defaultdict
import csv

waterway_code_dict={1:"LCM",2:"SCM"}
gender_code_dict={1:"Men",2:"Women"}
distance_code_dict={1:"25M",2:"50M",3:"100M",4:"200M",5:"400M",6:"800M",7:"1500M"}
swimming_style_code_dict={1:"Fr",2:"Ba",3:"Br",4:"Fly",5:"IM",6:"FR",7:"MR"}
def get_keys_from_value(d, val):
    keys=[k for k, v in d.items() if v == val]
    if keys:
        return keys[0]
    return None

names=["瀬戸大也","本多灯"]
discribe=["Men","SCM","200M","Fly"]

gender_code=get_keys_from_value(gender_code_dict,discribe[0])
waterway_code=get_keys_from_value(waterway_code_dict,discribe[1])
distance_code=get_keys_from_value(distance_code_dict,discribe[2])
swimming_style_code=get_keys_from_value(swimming_style_code_dict,discribe[3])

nameList=[]
nameDict={}
#print('_'.join(names))
for n in names:
    swimmerName=n
    for i in range(2008,2023):
        jname=str(i)+"_"+str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])+"_200all"
        path='./concated/'+str(i)+'_rank200/'+jname+".json"
        year=i
        with open(path) as f:
            s = f.read()
            dat = dict(json.loads(s))['data']
            for k,i in enumerate(dat):
                #print(i["swimmers"]["swimmer_name"])
                name=i["swimmers"]["swimmer_name"].replace('　', '').replace(' ', '')
                info=i["record"]
                info["year"]=year
                #print(i["record"]["achieve_date"])
                info['entry_group']=i["swimmers"]['entry_group']
                if name==swimmerName:
                    #print(info)
                    nameList.append(info)
    nameDict[swimmerName]=nameList
#pprint(nameDict)
filename=str(gender_code_dict[gender_code])+"_"+str(waterway_code_dict[waterway_code])+"_"+str(distance_code_dict[distance_code])+"_"+str(swimming_style_code_dict[swimming_style_code])
with open('./namesbox/'+'_'.join(names)+"_"+filename+'.csv', 'w') as f:
    writer = csv.writer(f)
    for swimmerName in names:
        for k in nameDict[swimmerName]:
            print(k)
            writer.writerow([swimmerName,k["year"],k["entry_group"]["name"],k['record'],k["achieve_date"]])
# Out:
# {'id': 4824940, 'is_relay_first': False, 'record': '1:55.31', 'achieve_date': '2010年01月31日(日)', 'is_new': False, 'year': 2009, 'entry_group': {'code': '11605', 'name': 'JSS毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 11006362, 'is_relay_first': False, 'record': '1:56.88', 'achieve_date': '2010年05月09日(日)', 'is_new': False, 'year': 2010, 'entry_group': {'code': '11605', 'name': 'ＪＳＳ毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 18992369, 'is_relay_first': False, 'record': '1:55.94', 'achieve_date': '2011年06月05日(日)', 'is_new': False, 'year': 2011, 'entry_group': {'code': '11605', 'name': 'ＪＳＳ毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 14037403, 'is_relay_first': False, 'record': '1:51.30', 'achieve_date': '2012年10月06日(土)', 'is_new': False, 'year': 2012, 'entry_group': {'code': '11605', 'name': 'ＪＳＳ毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 15213733, 'is_relay_first': False, 'record': '1:50.93', 'achieve_date': '2014年02月15日(土)', 'is_new': False, 'year': 2013, 'entry_group': {'code': '11605', 'name': 'ＪＳＳ毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 5937339, 'is_relay_first': False, 'record': '1:48.92', 'achieve_date': '2014年12月07日(日)', 'is_new': False, 'year': 2014, 'entry_group': {'code': '48056', 'name': '早稲田大', 'short_name': '早稲田大', 'member_group': {'code': 48, 'name': '関東支部'}}}
# {'id': 8477320, 'is_relay_first': False, 'record': '1:51.65', 'achieve_date': '2015年04月19日(日)', 'is_new': False, 'year': 2015, 'entry_group': {'code': '48056', 'name': '早稲田大', 'short_name': '早稲田大', 'member_group': {'code': 48, 'name': '関東支部'}}}
# {'id': 16971584, 'is_relay_first': False, 'record': '1:49.53', 'achieve_date': '2016年10月22日(土)', 'is_new': False, 'year': 2016, 'entry_group': {'code': '48056', 'name': '早稲田大', 'short_name': '早稲田大', 'member_group': {'code': 48, 'name': '関東支部'}}}
# {'id': 20651695, 'is_relay_first': False, 'record': '1:54.50', 'achieve_date': '2017年05月07日(日)', 'is_new': False, 'year': 2017, 'entry_group': {'code': '13758', 'name': 'ＡＮＡ', 'short_name': 'ＡＮＡ', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 11882569, 'is_relay_first': False, 'record': '1:48.24', 'achieve_date': '2018年12月11日(火)', 'is_new': False, 'year': 2018, 'entry_group': {'code': '13758', 'name': 'ＡＮＡ', 'short_name': 'ＡＮＡ', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 22401055, 'is_relay_first': False, 'record': '1:50.36', 'achieve_date': '2021年10月16日(土)', 'is_new': False, 'year': 2021, 'entry_group': {'code': '13546', 'name': 'TEAM DAIYA', 'short_name': 'TEAM DAIYA', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 22407960, 'is_relay_first': False, 'record': '1:56.80', 'achieve_date': '2017年03月29日(水)', 'is_new': False, 'year': 2016, 'entry_group': {'code': '14631', 'name': 'ATSC.YW', 'short_name': 'ATSC.YW', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 19671288, 'is_relay_first': False, 'record': '1:55.91', 'achieve_date': '2018年03月29日(木)', 'is_new': False, 'year': 2017, 'entry_group': {'code': '14631', 'name': 'ATSC.YW', 'short_name': 'ATSC.YW', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 11634201, 'is_relay_first': False, 'record': '1:54.35', 'achieve_date': '2018年10月27日(土)', 'is_new': False, 'year': 2018, 'entry_group': {'code': '14631', 'name': 'ATSC.YW', 'short_name': 'ATSC.YW', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 7202897, 'is_relay_first': False, 'record': '1:53.45', 'achieve_date': '2019年10月26日(土)', 'is_new': False, 'year': 2019, 'entry_group': {'code': '14057', 'name': '日大藤沢', 'short_name': '日大藤沢', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 12924963, 'is_relay_first': False, 'record': '1:52.75', 'achieve_date': '2020年10月17日(土)', 'is_new': False, 'year': 2020, 'entry_group': {'code': '48057', 'name': '日本大', 'short_name': '日本大', 'member_group': {'code': 48, 'name': '関東支部'}}}
# {'id': 22401056, 'is_relay_first': False, 'record': '1:49.84', 'achieve_date': '2021年10月16日(土)', 'is_new': False, 'year': 2021, 'entry_group': {'code': '14631', 'name': 'ATSC.YW', 'short_name': 'ATSC.YW', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 4824940, 'is_relay_first': False, 'record': '1:55.31', 'achieve_date': '2010年01月31日(日)', 'is_new': False, 'year': 2009, 'entry_group': {'code': '11605', 'name': 'JSS毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 11006362, 'is_relay_first': False, 'record': '1:56.88', 'achieve_date': '2010年05月09日(日)', 'is_new': False, 'year': 2010, 'entry_group': {'code': '11605', 'name': 'ＪＳＳ毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 18992369, 'is_relay_first': False, 'record': '1:55.94', 'achieve_date': '2011年06月05日(日)', 'is_new': False, 'year': 2011, 'entry_group': {'code': '11605', 'name': 'ＪＳＳ毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 14037403, 'is_relay_first': False, 'record': '1:51.30', 'achieve_date': '2012年10月06日(土)', 'is_new': False, 'year': 2012, 'entry_group': {'code': '11605', 'name': 'ＪＳＳ毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 15213733, 'is_relay_first': False, 'record': '1:50.93', 'achieve_date': '2014年02月15日(土)', 'is_new': False, 'year': 2013, 'entry_group': {'code': '11605', 'name': 'ＪＳＳ毛呂山', 'short_name': 'ＪＳＳ毛呂山', 'member_group': {'code': 11, 'name': '埼玉'}}}
# {'id': 5937339, 'is_relay_first': False, 'record': '1:48.92', 'achieve_date': '2014年12月07日(日)', 'is_new': False, 'year': 2014, 'entry_group': {'code': '48056', 'name': '早稲田大', 'short_name': '早稲田大', 'member_group': {'code': 48, 'name': '関東支部'}}}
# {'id': 8477320, 'is_relay_first': False, 'record': '1:51.65', 'achieve_date': '2015年04月19日(日)', 'is_new': False, 'year': 2015, 'entry_group': {'code': '48056', 'name': '早稲田大', 'short_name': '早稲田大', 'member_group': {'code': 48, 'name': '関東支部'}}}
# {'id': 16971584, 'is_relay_first': False, 'record': '1:49.53', 'achieve_date': '2016年10月22日(土)', 'is_new': False, 'year': 2016, 'entry_group': {'code': '48056', 'name': '早稲田大', 'short_name': '早稲田大', 'member_group': {'code': 48, 'name': '関東支部'}}}
# {'id': 20651695, 'is_relay_first': False, 'record': '1:54.50', 'achieve_date': '2017年05月07日(日)', 'is_new': False, 'year': 2017, 'entry_group': {'code': '13758', 'name': 'ＡＮＡ', 'short_name': 'ＡＮＡ', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 11882569, 'is_relay_first': False, 'record': '1:48.24', 'achieve_date': '2018年12月11日(火)', 'is_new': False, 'year': 2018, 'entry_group': {'code': '13758', 'name': 'ＡＮＡ', 'short_name': 'ＡＮＡ', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 22401055, 'is_relay_first': False, 'record': '1:50.36', 'achieve_date': '2021年10月16日(土)', 'is_new': False, 'year': 2021, 'entry_group': {'code': '13546', 'name': 'TEAM DAIYA', 'short_name': 'TEAM DAIYA', 'member_group': {'code': 13, 'name': '東京'}}}
# {'id': 22407960, 'is_relay_first': False, 'record': '1:56.80', 'achieve_date': '2017年03月29日(水)', 'is_new': False, 'year': 2016, 'entry_group': {'code': '14631', 'name': 'ATSC.YW', 'short_name': 'ATSC.YW', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 19671288, 'is_relay_first': False, 'record': '1:55.91', 'achieve_date': '2018年03月29日(木)', 'is_new': False, 'year': 2017, 'entry_group': {'code': '14631', 'name': 'ATSC.YW', 'short_name': 'ATSC.YW', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 11634201, 'is_relay_first': False, 'record': '1:54.35', 'achieve_date': '2018年10月27日(土)', 'is_new': False, 'year': 2018, 'entry_group': {'code': '14631', 'name': 'ATSC.YW', 'short_name': 'ATSC.YW', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 7202897, 'is_relay_first': False, 'record': '1:53.45', 'achieve_date': '2019年10月26日(土)', 'is_new': False, 'year': 2019, 'entry_group': {'code': '14057', 'name': '日大藤沢', 'short_name': '日大藤沢', 'member_group': {'code': 14, 'name': '神奈川'}}}
# {'id': 12924963, 'is_relay_first': False, 'record': '1:52.75', 'achieve_date': '2020年10月17日(土)', 'is_new': False, 'year': 2020, 'entry_group': {'code': '48057', 'name': '日本大', 'short_name': '日本大', 'member_group': {'code': 48, 'name': '関東支部'}}}
# {'id': 22401056, 'is_relay_first': False, 'record': '1:49.84', 'achieve_date': '2021年10月16日(土)', 'is_new': False, 'year': 2021, 'entry_group': {'code': '14631', 'name': 'ATSC.YW', 'short_name': 'ATSC.YW', 'member_group': {'code': 14, 'name': '神奈川'}}}
